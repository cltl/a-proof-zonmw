# %%
import pandas as pd
from pathlib import Path
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
path = Path('../../data/expr_july/clf_levels_ADM_sents')

test = pd.read_pickle(path / 'test.pkl')

# %%
test.head()
# Out:
#                     pad_sen_id institution  year       MDN  NotitieID  \
# pad_sen_id
# 150256243_0073  150256243_0073         amc  2017   8309478  150256243
# 150256243_0074  150256243_0074         amc  2017   8309478  150256243
# 150256243_0075  150256243_0075         amc  2017   8309478  150256243
# 150404230_0070  150404230_0070        vumc  2017  Z3893942  150404230
# 158325874_0005  158325874_0005         amc  2017   1195297  158325874
#
#                      batch annotator  background_sent  target_sent  \
# pad_sen_id
# 150256243_0073     week_16  vervaart            False        False
# 150256243_0074     week_16  vervaart            False        False
# 150256243_0075     week_16  vervaart            False        False
# 150404230_0070     week_18   meskers            False        False
# 158325874_0005  week_22-26   opsomer            False        False
#
#                                                          text_raw  labels  \
# pad_sen_id
# ...
