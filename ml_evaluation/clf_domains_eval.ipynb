# %% [markdown]
# # Evaluation of domain classifiers
#
# - Multi-label classification on sentence-level;
# - Evaluation on sentence-level + aggregation on note-level;
# - Each domain is evaluated independently.

# %%
import pandas as pd
from pathlib import Path
from sklearn.metrics import precision_score, recall_score, f1_score

import sys
sys.path.insert(0, '..')
from utils.config import PATHS

# %%
pd.set_option('max_columns', None)
pd.set_option('max_colwidth', None)

# %% [markdown]
# # Config
#
# Define:
#
# - list of domains,
# - path to dir where a pickled test file with predictions is located,
# - the predictions column to be evaluated.

# %%
domains = ['ADM', 'ATT', 'BER', 'ENR', 'ETN', 'FAC', 'INS', 'MBW', 'STM']

pred_col = 'pred_domains_add_pilot'

datapath = 'data_expr_july'
testdir = 'clf_domains'
testpath = PATHS.getpath(datapath) / testdir / 'test.pkl'

# %% [markdown]
# # Load and process data

# %%
# raw predictions are a list in a list, e.g. [[0, 1, 0, 0]];
# `preds` columns flattens them to a list.
# domains column is needed for the explosion in the next cell.

df = pd.read_pickle(testpath).assign(
    preds = lambda df: df[pred_col].str[0],
    domains = lambda df: [domains] * len(df),
)

# %%
results = df.explode(
    ['domains', 'labels', 'preds']
)[['pad_sen_id', 'NotitieID', 'annotator', 'domains', 'labels', 'preds']].reset_index()

# %% [markdown]
# # Sentence level evaluation

# %% [markdown]
# ## Precision, recall, F1-score

# %%
def make_classreport(domain):
    y_true = results.query(f"domains == '{domain}'").labels.astype(int)
    y_pred = results.query(f"domains == '{domain}'").preds.astype(int)
    precision = precision_score(y_true, y_pred, zero_division=0).round(2)
    recall = recall_score(y_true, y_pred, zero_division=0).round(2)
    f1 = f1_score(y_true, y_pred).round(2)
    support = sum(y_true)
    return pd.Series(
        index = ['precision', 'recall', 'f1_score', 'support'],
        data = [precision, recall, f1, support],
        name = domain,
        dtype = object,
    )

pd.concat([make_classreport(domain) for domain in domains], axis=1)
# Out:
#             ADM   ATT   BER   ENR   ETN   FAC   INS   MBW   STM
# precision  0.65  0.83  0.31  0.72  0.51  0.49  0.42  0.58  0.53
# recall      0.6  0.47  0.62  0.66  0.66  0.82   0.4  0.83  0.76
# f1_score   0.63   0.6  0.42  0.69  0.57  0.62  0.41  0.68  0.62
# support     405    32    26    98   178   136   133    64   155

# %% [markdown]
# ## Error analysis

# %%
results = results.merge(
    df[['pad_sen_id', 'background_sent', 'target_sent']],
    how='left',
    on='pad_sen_id',
).assign(
    background = lambda df: df.background_sent | df.target_sent,
    correct = lambda df: df.labels == df.preds,
)

# %%
not_correct = results.query("not correct")
false_pos = results.query("not correct and labels == 0")
false_neg = results.query("not correct and labels == 1")

# %% [markdown]
# ### Confusion matrix

# %%
def find_confusion(df, domain):
    query1 = f"domains == '{domain}' and not correct and labels == 1"
    query2 = f"domains != '{domain}' and not correct and preds == 1"
    fneg_sents = set(df.query(query1).pad_sen_id)
    select_sents = "pad_sen_id in @fneg_sents"
    s = df.query(select_sents).query(query2).groupby('domains').size()
    return s.rename(domain)

def align_series(s, doms):
    output = pd.Series(index=doms, name=s.name, dtype='float')
    output.update(s)
    return output

confusions = [find_confusion(results, domain) for domain in domains]
confusions = [align_series(s, domains) for s in confusions]

# %%
def find_truepos(df, domain):
    query = f"domains == '{domain}' and correct and labels == 1"
    return len(df.query(query))

truepos = {domain:find_truepos(results, domain) for domain in domains}

# %%
def find_fneg(df, domain):
    query1 = f"domains == '{domain}' and not correct and labels == 1"
    query2 = f"domains != '{domain}' and correct"
    fneg_sents = set(df.query(query1).pad_sen_id)
    select_sents = "pad_sen_id in @fneg_sents"
    return df.query(select_sents).query(query2).pad_sen_id.nunique()
fneg = {domain:find_fneg(results, domain) for domain in domains}
fneg = pd.Series(fneg, name='&lt;none&gt;')

# %%
def find_fpos(df, domain):
    query1 = f"domains == '{domain}' and not correct and labels == 0"
    query2 = f"domains != '{domain}' and correct"
    fneg_sents = set(df.query(query1).pad_sen_id)
    select_sents = "pad_sen_id in @fneg_sents"
    return df.query(select_sents).query(query2).pad_sen_id.nunique()
fpos = {domain:find_fpos(results, domain) for domain in domains}
fpos = pd.Series(fpos, name='&lt;none&gt;')

# %%
matrix = pd.concat(confusions, axis=1).sort_index()
for key, val in truepos.items():
    matrix.loc[key, key] = val
matrix = matrix.append(fneg).join(fpos)

# %%
matrix.fillna(0).astype(int).style.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_80f7b_row0_col0, #T_80f7b_row0_col9, #T_80f7b_row2_col2, #T_80f7b_row3_col3, #T_80f7b_row4_col4, #T_80f7b_row5_col5, #T_80f7b_row7_col7, #T_80f7b_row8_col8, #T_80f7b_row9_col1, #T_80f7b_row9_col6 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_80f7b_row0_col1, #T_80f7b_row0_col2, #T_80f7b_row0_col7, #T_80f7b_row1_col0, #T_80f7b_row1_col2, #T_80f7b_row1_col3, #T_80f7b_row1_col4, #T_80f7b_row1_col5, #T_80f7b_row1_col6, #T_80f7b_row1_col7, #T_80f7b_row2_col0, #T_80f7b_row2_col1, #T_80f7b_row2_col4, #T_80f7b_row2_col5, #T_80f7b_row2_col7, #T_80f7b_row2_col8, #T_80f7b_row3_col1, #T_80f7b_row3_col2, #T_80f7b_row3_col4, #T_80f7b_row3_col5, #T_80f7b_row3_col6, #T_80f7b_row3_col7, #T_80f7b_row3_col8, #T_80f7b_row4_col0, #T_80f7b_row4_col1, #T_80f7b_row4_col2, #T_80f7b_row4_col3, #T_80f7b_row4_col5, #T_80f7b_row4_col6, #T_80f7b_row4_col7, #T_80f7b_row4_col8, #T_80f7b_row5_col2, #T_80f7b_row5_col7, #T_80f7b_row5_col8, #T_80f7b_row6_col2, #T_80f7b_row6_col4, #T_80f7b_row7_col0, #T_80f7b_row7_col1, #T_80f7b_row7_col2, #T_80f7b_row7_col3, #T_80f7b_row7_col4, #T_80f7b_row7_col5, #T_80f7b_row7_col6, #T_80f7b_row8_col0, #T_80f7b_row8_col1, #T_80f7b_row8_col2, #T_80f7b_row8_col4, #T_80f7b_row8_col5, #T_80f7b_row8_col6, #T_80f7b_row8_col7, #T_80f7b_row9_col9 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_80f7b_row0_col3, #T_80f7b_row2_col3, #T_80f7b_row2_col6, #T_80f7b_row5_col3, #T_80f7b_row8_col3 {
#   background-color: #f5fbf3;
#   color: #000000;
# }
# #T_80f7b_row0_col4, #T_80f7b_row0_col5, #T_80f7b_row1_col8, #T_80f7b_row3_col0, #T_80f7b_row5_col0, #T_80f7b_row5_col4, #T_80f7b_row6_col0, #T_80f7b_row6_col5, #T_80f7b_row6_col8, #T_80f7b_row7_col8 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_80f7b_row0_col6 {
#   background-color: #f2faef;
#   color: #000000;
# }
# #T_80f7b_row0_col8, #T_80f7b_row6_col7 {
#   background-color: #f5fbf2;
#   color: #000000;
# }
# #T_80f7b_row1_col1 {
#   background-color: #006b2b;
#   color: #f1f1f1;
# }
# #T_80f7b_row1_col9 {
#   background-color: #f4fbf2;
#   color: #000000;
# }
# #T_80f7b_row2_col9 {
#   background-color: #c2e7bb;
#   color: #000000;
# }
# #T_80f7b_row3_col9 {
#   background-color: #d6efd0;
#   color: #000000;
# }
# #T_80f7b_row4_col9 {
#   background-color: #03702e;
#   color: #f1f1f1;
# }
# #T_80f7b_row5_col1, #T_80f7b_row6_col1 {
#   background-color: #eff9eb;
#   color: #000000;
# }
# #T_80f7b_row5_col6 {
#   background-color: #e7f6e3;
#   color: #000000;
# }
# #T_80f7b_row5_col9 {
#   background-color: #00692a;
#   color: #f1f1f1;
# }
# #T_80f7b_row6_col3 {
#   background-color: #f3faf0;
#   color: #000000;
# }
# #T_80f7b_row6_col6 {
#   background-color: #38a156;
#   color: #f1f1f1;
# }
# #T_80f7b_row6_col9 {
#   background-color: #60ba6c;
#   color: #f1f1f1;
# }
# #T_80f7b_row7_col9 {
#   background-color: #bbe4b4;
#   color: #000000;
# }
# #T_80f7b_row8_col9 {
#   background-color: #147e3a;
#   color: #f1f1f1;
# }
# #T_80f7b_row9_col0 {
#   background-color: #3aa357;
#   color: #f1f1f1;
# }
# #T_80f7b_row9_col2 {
#   background-color: #40aa5d;
#   color: #f1f1f1;
# }
# #T_80f7b_row9_col3 {
#   background-color: #72c375;
#   color: #000000;
# }
# #T_80f7b_row9_col4 {
#   background-color: #6bc072;
#   color: #000000;
# }
# #T_80f7b_row9_col5 {
#   background-color: #d0edca;
#   color: #000000;
# }
# #T_80f7b_row9_col7 {
#   background-color: #d1edcb;
#   color: #000000;
# }
# #T_80f7b_row9_col8 {
#   background-color: #b4e1ad;
#   color: #000000;
# }
# </style>
# <table id="T_80f7b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >ADM</th>
#       <th class="col_heading level0 col1" >ATT</th>
#       <th class="col_heading level0 col2" >BER</th>
#       <th class="col_heading level0 col3" >ENR</th>
#       <th class="col_heading level0 col4" >ETN</th>
#       <th class="col_heading level0 col5" >FAC</th>
#       <th class="col_heading level0 col6" >INS</th>
#       <th class="col_heading level0 col7" >MBW</th>
#       <th class="col_heading level0 col8" >STM</th>
#       <th class="col_heading level0 col9" >&lt;none&gt;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_80f7b_level0_row0" class="row_heading level0 row0" >ADM</th>
#       <td id="T_80f7b_row0_col0" class="data row0 col0" >245</td>
#       <td id="T_80f7b_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_80f7b_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_80f7b_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_80f7b_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_80f7b_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_80f7b_row0_col6" class="data row0 col6" >3</td>
#       <td id="T_80f7b_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_80f7b_row0_col8" class="data row0 col8" >2</td>
#       <td id="T_80f7b_row0_col9" class="data row0 col9" >131</td>
#     </tr>
#     <tr>
#       <th id="T_80f7b_level0_row1" class="row_heading level0 row1" >ATT</th>
#       <td id="T_80f7b_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_80f7b_row1_col1" class="data row1 col1" >15</td>
#       <td id="T_80f7b_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_80f7b_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_80f7b_row1_col4" class="data row1 col4" >0</td>
#       <td id="T_80f7b_row1_col5" class="data row1 col5" >0</td>
#       <td id="T_80f7b_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_80f7b_row1_col7" class="data row1 col7" >0</td>
#       <td id="T_80f7b_row1_col8" class="data row1 col8" >1</td>
#       <td id="T_80f7b_row1_col9" class="data row1 col9" >3</td>
#     </tr>
#     <tr>
#       <th id="T_80f7b_level0_row2" class="row_heading level0 row2" >BER</th>
#       <td id="T_80f7b_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_80f7b_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_80f7b_row2_col2" class="data row2 col2" >16</td>
#       <td id="T_80f7b_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_80f7b_row2_col4" class="data row2 col4" >0</td>
#       <td id="T_80f7b_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_80f7b_row2_col6" class="data row2 col6" >1</td>
#       <td id="T_80f7b_row2_col7" class="data row2 col7" >0</td>
#       <td id="T_80f7b_row2_col8" class="data row2 col8" >0</td>
#       <td id="T_80f7b_row2_col9" class="data row2 col9" >35</td>
#     </tr>
#     <tr>
#       <th id="T_80f7b_level0_row3" class="row_heading level0 row3" >ENR</th>
#       <td id="T_80f7b_row3_col0" class="data row3 col0" >1</td>
#       <td id="T_80f7b_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_80f7b_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_80f7b_row3_col3" class="data row3 col3" >65</td>
#       <td id="T_80f7b_row3_col4" class="data row3 col4" >0</td>
#       <td id="T_80f7b_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_80f7b_row3_col6" class="data row3 col6" >0</td>
#       <td id="T_80f7b_row3_col7" class="data row3 col7" >0</td>
#       <td id="T_80f7b_row3_col8" class="data row3 col8" >0</td>
#       <td id="T_80f7b_row3_col9" class="data row3 col9" >25</td>
#     </tr>
#     <tr>
#       <th id="T_80f7b_level0_row4" class="row_heading level0 row4" >ETN</th>
#       <td id="T_80f7b_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_80f7b_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_80f7b_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_80f7b_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_80f7b_row4_col4" class="data row4 col4" >117</td>
#       <td id="T_80f7b_row4_col5" class="data row4 col5" >0</td>
#       <td id="T_80f7b_row4_col6" class="data row4 col6" >0</td>
#       <td id="T_80f7b_row4_col7" class="data row4 col7" >0</td>
#       <td id="T_80f7b_row4_col8" class="data row4 col8" >0</td>
#       <td id="T_80f7b_row4_col9" class="data row4 col9" >113</td>
#     </tr>
#     <tr>
#       <th id="T_80f7b_level0_row5" class="row_heading level0 row5" >FAC</th>
#       <td id="T_80f7b_row5_col0" class="data row5 col0" >2</td>
#       <td id="T_80f7b_row5_col1" class="data row5 col1" >1</td>
#       <td id="T_80f7b_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_80f7b_row5_col3" class="data row5 c

# %% [markdown]
# ### False positives

# %% [markdown]
# #### Background/target sentences

# %%
# proportion of background out of false positives

pd.concat([
    pd.crosstab(
        index=false_pos.domains,
        columns=false_pos.background,
        aggfunc='count',
        values=false_pos.pad_sen_id,
        normalize='index',
    ).mul(100).round(1),
    pd.crosstab(
        index=false_pos.domains,
        columns=false_pos.background,
        aggfunc='count',
        values=false_pos.pad_sen_id,
    ).fillna(0).astype(int),
], keys=['percentage', 'count'], axis=1
)
# Out:
#            percentage       count
# background      False  True False True
# domains
# ADM              74.0  26.0    97   34
# ATT              66.7  33.3     2    1
# BER              77.1  22.9    27    8
# ENR              60.0  40.0    15   10
# ETN              72.6  27.4    82   31
# FAC              66.4  33.6    77   39
# INS              76.4  23.6    55   17
# MBW              78.9  21.1    30    8
# STM              82.9  17.1    87   18

# %%
# random example

q = "domains == 'STM' and background"
example = false_pos.query(q).pad_sen_id.sample(1)
df.query(f"pad_sen_id == '{example.iloc[0]}'")[['pad_sen_id', 'text']]
# Out:
#             pad_sen_id                    text
# 149762  407195723_0058  Voelt zich opgelucht .

# %% [markdown]
# #### Not background/target

# %%
# random example

q = "domains == 'MBW' and not background"
example = false_pos.query(q).pad_sen_id.sample(1)
df.query(f"pad_sen_id == '{example.iloc[0]}'")[['pad_sen_id', 'text']]
# Out:
#             pad_sen_id               text
# 212244  253217006_0027  Niet afgevallen .

# %% [markdown]
# ### False negatives

# %%
# random example

q = "domains == 'INS'"
example = false_neg.query(q).pad_sen_id.sample(1)
df.query(f"pad_sen_id == '{example.iloc[0]}'")[['pad_sen_id', 'text']]
# Out:
#            pad_sen_id                       text
# 24474  413727342_0038  Zit nog niet op uit bed .

# %% [markdown]
# # Note level evaluation

# %%
notes = results.astype({
    'labels': bool, 'preds': bool
}).groupby([
    'NotitieID', 'domains',
])[['labels', 'preds']].any().assign(
    correct = lambda df: df.labels == df.preds,
).reset_index(level=1)

# %% [markdown]
# ## Precision, recall, F1-score

# %%
def make_classreport(domain):
    y_true = notes.query(f"domains == '{domain}'").labels.astype(int)
    y_pred = notes.query(f"domains == '{domain}'").preds.astype(int)
    precision = precision_score(y_true, y_pred, zero_division=0).round(2)
    recall = recall_score(y_true, y_pred, zero_division=0).round(2)
    f1 = f1_score(y_true, y_pred).round(2)
    support = sum(y_true)
    return pd.Series(
        index = ['precision', 'recall', 'f1_score', 'support'],
        data = [precision, recall, f1, support],
        name = domain,
        dtype = object,
    )

pd.concat([make_classreport(domain) for domain in domains], axis=1)
# Out:
#             ADM   ATT   BER   ENR   ETN   FAC   INS   MBW   STM
# precision  0.86  0.88  0.41  0.81  0.71  0.68  0.64  0.69  0.65
# recall     0.87  0.67  0.73   0.8  0.75  0.92   0.6  0.93  0.91
# f1_score   0.87  0.76  0.52   0.8  0.73  0.78  0.62  0.79  0.76
# support     199    21    22    69   123    80    75    45    85

# %% [markdown]
# ## Impact background/target
#
# To estimate the impact of background/target sentences, I remove them from the test set and repeat the evaluation.

# %%
background_sents = df.query(
    "(background_sent or target_sent) and labels.astype('str') == '[0, 0, 0, 0, 0, 0, 0, 0, 0]'"
).pad_sen_id.to_list()

# %%
no_bckgrnd = results.loc[~results.pad_sen_id.isin(background_sents)].astype({
    'labels': bool, 'preds': bool
}).groupby([
    'NotitieID', 'domains',
])[['labels', 'preds']].any().assign(
    correct = lambda df: df.labels == df.preds,
).reset_index(level=1)

# %%
def make_classreport(domain):
    y_true = no_bckgrnd.query(f"domains == '{domain}'").labels.astype(int)
    y_pred = no_bckgrnd.query(f"domains == '{domain}'").preds.astype(int)
    precision = precision_score(y_true, y_pred, zero_division=0).round(2)
    recall = recall_score(y_true, y_pred, zero_division=0).round(2)
    f1 = f1_score(y_true, y_pred).round(2)
    support = sum(y_true)
    return pd.Series(
        index = ['precision', 'recall', 'f1_score', 'support'],
        data = [precision, recall, f1, support],
        name = domain,
        dtype = object,
    )

pd.concat([make_classreport(domain) for domain in domains], axis=1)
# Out:
#             ADM   ATT   BER   ENR   ETN   FAC   INS   MBW   STM
# precision  0.87  0.93  0.48  0.86  0.74  0.73   0.7  0.71  0.68
# recall     0.85  0.67  0.68  0.78  0.75  0.92  0.59  0.93  0.89
# f1_score   0.86  0.78  0.57  0.82  0.74  0.81  0.64  0.81  0.77
# support     199    21    22    69   123    80    75    45    85
