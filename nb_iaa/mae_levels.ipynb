# %% [markdown]
# # Mean absolute error as IAA measure

# %%
import pandas as pd
from sklearn.metrics import mean_absolute_error
from itertools import permutations, combinations

import sys
sys.path.insert(0, '..')
from utils.config import PATHS
from utils.data_process import drop_disregard, fix_week_14, pad_sen_id

# %% [markdown]
# ## Load and pre-process data

# %%
# load annotations

path = PATHS.getpath('data') / 'iaa'

df = pd.concat([pd.read_pickle(fp) for fp in path.glob('*_parsed.pkl')], ignore_index=True)

# %%
# load batch info

path = PATHS.getpath('data_to_inception_conll')

info = pd.DataFrame()

for batch in df.batch.unique():
    batch_info = pd.read_pickle(path / f'{batch}.pkl').assign(
        batch = batch,
    )
    info = info.append(batch_info, ignore_index=True)

# %%
# select IAA files

iaa = info.query("samp_meth == 'kwd_iaa'").NotitieID.unique()
df = df.loc[df.NotitieID.isin(iaa)]

# %%
# process annotations

domains = ['ADM', 'ATT', 'BER', 'ENR', 'ETN', 'FAC', 'INS', 'MBW', 'STM']
levels = [f"{domain}_lvl" for domain in domains]
other = ['target', 'background', 'plus']

df = df.assign(
    background_sent = lambda df: df.groupby('sen_id').background.transform('any'),
    target_sent = lambda df: df.groupby('sen_id').target.transform('any'),
    disregard_note = lambda df: df.groupby('NotitieID').disregard.transform('any'),
    pad_sen_id = df.sen_id.apply(pad_sen_id),
).pipe(fix_week_14)

df[domains + other] = df[domains + other].fillna(False)

# %%
# replace annotaotr names with alias (first letter)

df.annotator = df.annotator.str[0]

# %% [markdown]
# ## Create sentence-level labels

# %%
# select notes that were annotated by all 6 annotators
# (needed since some annotators skipped some of the batches);
# create a sentence-level label for each domain

sent_labels = df.groupby(['annotator', 'pad_sen_id'])[levels].mean().unstack(0).stack(0)

# %% [markdown]
# ## Pairwise metrics

# %%
pairs = list(permutations(sent_labels.columns, r=2))
combis = list(combinations(sent_labels.columns, r=2))

# %%
cols = [
    'annotator1',
    'annotator2',
    'level',
    'support',
    'mae',
]
classreport = pd.DataFrame(columns=cols)
for annotator1, annotator2 in combis:
    for level in levels:
        ys = sent_labels.xs(level, level=1)[[annotator1, annotator2]].dropna()
        if ys.empty:
            continue
        data = pd.DataFrame(index=[0]).assign(
            annotator1 = annotator1,
            annotator2 = annotator2,
            level = level,
            support = len(ys),
            mae = mean_absolute_error(ys[annotator1], ys[annotator2]),
        )
        classreport = classreport.append(data, ignore_index=True)

# %% [markdown]
# ## Average F1-score per domain

# %%
classreport.groupby('level').agg({
    'mae': lambda s: round(s.mean(), 2),
    'support': lambda s: [s.min(), s.max()],
}).T
# Out:
# level     ADM_lvl ATT_lvl BER_lvl  ENR_lvl  ETN_lvl  FAC_lvl  INS_lvl MBW_lvl  \
# mae          0.25    0.32    0.38     0.39     0.28     0.17      0.3    0.32
# support  [15, 26]  [1, 3]  [1, 3]  [7, 11]  [4, 16]  [7, 14]  [1, 10]  [1, 4]
#
# level    STM_lvl
# mae         0.31
# support  [6, 19]

# %% [markdown]
# ## Average F1-score per domain

# %%
table = classreport.set_index(['annotator1', 'annotator2', 'level']).unstack(-1).xs('mae', axis=1, level=0).reset_index().rename_axis('', axis=1)
table.loc[15,'ADM_lvl':] = table.loc[:,'ADM_lvl':].mean()
table.loc[15,'annotator1'] = 'mean'
table.loc[15,'annotator2'] = ''

table.style.background_gradient(cmap='Greens', axis=None).format({level:"{:.2}" for level in levels}, na_rep='N/A').apply(lambda s: len(s) * ["background: black; color: white"],subset=15)
# Out:
# <style type="text/css">
# #T_a7d30_row0_col2, #T_a7d30_row11_col2 {
#   background-color: #cbeac4;
#   color: #000000;
# }
# #T
{
#   background-color: #e9f7e5;
#   color: #000000;
# }
# #T_a7d30_row7_col9 {
#   background-color: #37a055;
#   color: #f1f1f1;
# }
# #T_a7d30_row7_col10 {
#   background-color: #a9dca3;
#   color: #000000;
# }
# #T_a7d30_row8_col2 {
#   background-color: #c4e8bd;
#   color: #000000;
# }
# #T_a7d30_row8_col7, #T_a7d30_row11_col10 {
#   background-color: #ceecc8;
#   color: #000000;
# }
# #T_a7d30_row8_col9 {
#   background-color: #228a44;
#   color: #f1f1f1;
# }
# #T_a7d30_row9_col2 {
#   background-color: #eaf7e6;
#   color: #000000;
# }
# #T_a7d30_row9_col10, #T_a7d30_row14_col6 {
#   background-color: #e5f5e0;
#   color: #000000;
# }
# #T_a7d30_row10_col2 {
#   background-color: #c0e6b9;
#   color: #000000;
# }
# #T_a7d30_row10_col5 {
#   background-color: #006c2c;
#   color: #f1f1f1;
# }
# #T_a7d30_row10_col6, #T_a7d30_row10_col8, #T_a7d30_row11_col5 {
#   background-color: #a0d99b;
#   color: #000000;
# }
# #T_a7d30_row10_col10 {
#   background-color: #a7dba0;
#   color: #000000;
# }
# #T_a7d30_row11_col6 {
#   background-color: #81ca81;
#   color: #000000;
# }
# #T_a7d30_row12_col2 {
#   background-color: #cbebc5;
#   color: #000000;
# }
# #T_a7d30_row12_col10 {
#   background-color: #ebf7e7;
#   color: #000000;
# }
# #T_a7d30_row14_col8 {
#   background-color: #2c944c;
#   color: #f1f1f1;
# }
# #T_a7d30_row14_col10 {
#   background-color: #53b466;
#   color: #f1f1f1;
# }
# #T_a7d30_row15_col0, #T_a7d30_row15_col1 {
#   background: black;
#   color: white;
# }
# #T_a7d30_row15_col2 {
#   background-color: #c8e9c1;
#   color: #000000;
#   background: black;
#   color: white;
# }
# #T_a7d30_row15_col3, #T_a7d30_row15_col9 {
#   background-color: #b1e0ab;
#   color: #000000;
#   background: black;
#   color: white;
# }
# #T_a7d30_row15_col4 {
#   background-color: #9ed798;
#   color: #000000;
#   background: black;
#   color: white;
# }
# #T_a7d30_row15_col5 {
#   background-color: #9bd696;
#   color: #000000;
#   background: black;
#   color: white;
# }
# #T_a7d30_row15_col6 {
#   background-color: #bee5b8;
#   color: #000000;
#   background: black;
#   color: white;
# }
# #T_a7d30_row15_col7 {
#   background-color: #dbf1d6;
#   color: #000000;
#   background: black;
#   color: white;
# }
# #T_a7d30_row15_col8 {
#   background-color: #b8e3b2;
#   color: #000000;
#   background: black;
#   color: white;
# }
# #T_a7d30_row15_col10 {
#   background-color: #b6e2af;
#   color: #000000;
#   background: black;
#   color: white;
# }
# </style>
# <table id="T_a7d30_">
#   <thead>
#     <tr>
#       <th class="index_name level0" ></th>
#       <th class="col_heading level0 col0" >annotator1</th>
#       <th class="col_heading level0 col1" >annotator2</th>
#       <th class="col_heading level0 col2" >ADM_lvl</th>
#       <th class="col_heading level0 col3" >ATT_lvl</th>
#       <th class="col_heading level0 col4" >BER_lvl</th>
#       <th class="col_heading level0 col5" >ENR_lvl</th>
#       <th class="col_heading level0 col6" >ETN_lvl</th>
#       <th class="col_heading level0 col7" >FAC_lvl</th>
#       <th class="col_heading level0 col8" >INS_lvl</th>
#       <th class="col_heading level0 col9" >MBW_lvl</th>
#       <th class="col_heading level0 col10" >STM_lvl</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a7d30_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a7d30_row0_col0" class="data row0 col0" >a</td>
#       <td id="T_a7d30_row0_col1" class="data row0 col1" >k</td>
#       <td id="T_a7d30_row0_col2" class="data row0 col2" >0.23</td>
#       <td id="T_a7d30_row0_col3" class="data row0 col3" >N/A</td>
#       <td id="T_a7d30_row0_col4" class="data row0 col4" >0.0</td>
#       <td id="T_a7d30_row0_col5" class="data row0 col5" >0.2</td>
#       <td id="T_a7d30_row0_col6" class="data row0 col6" >0.27</td>
#       <td id="T_a7d30_row0_col7" class="data row0 col7" >0.0</td>
#       <td id="T_a7d30_row0_col8" class="data row0 col8" >0.0</td>
#       <td id="T_a7d30_row0_col9" class="data row0 col9" >0.5</td>
#       <td id="T_a7d30_row0_col10" class="data row0 col10" >0.22</td>
#     </tr>
#     <tr>
#       <th id="T_a7d30_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a7d30_row1_col0" class="data row1 col0" >a</td>
#       <td id="T_a7d30_row1_col1" class="data row1 col1" >m</td>
#       <td id="T_a7d30_row1_col2" class="data row1 col2" >0.19</td>
#       <td id="T_a7d30_row1_col3" class="data row1 c
